# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_outside = pd.read_csv('downloads/outside.csv')
data_inside = pd.read_csv('downloads/inside.csv')

# %%
pm03_outside_data = data_outside.loc[:,"time":"particles 03um"]
pm03_inside_data = data_inside.loc[:,"time":"particles 03um"]

# %%
y1 = pm03_outside_data['particles 03um']
y2 = pm03_inside_data['particles 03um'] 
plt.plot(y1, label = 'Outside')
plt.plot(y2,label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Particles 0.5um')
plt.title('Pm particles 0.3um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1,bins = 12,  label = 'Outside')
plt.hist(y2,bins= 12, label = 'Inside')
plt.xlabel('Particles 0.3um')
plt.ylabel('Frequency')
plt.title('Pm particles 0.3um Frequency')
plt.legend()
plt.show()

# %%
pm05_outside_data = data_outside.loc[:,"time":"particles 05um"]
pm05_inside_data = data_inside.loc[:,"time":"particles 05um"]
y3 = pm05_outside_data['particles 05um']
y4 = pm05_inside_data['particles 05um'] 
plt.plot(y3, label = 'Outside')
plt.plot(y4,label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Particles 0.5um')
plt.title('Pm particles 0.5um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y3,bins = 12,  label = 'Outside')
plt.hist(y4,bins= 12, label = 'Inside')
plt.xlabel('Particles 0.5um')
plt.ylabel('Frequency')
plt.title('Pm particles 0.5um Frequency')
plt.legend()
plt.show()

# %%
y1 = pm10_outside_data = data_outside.loc[:,"time":"particles 10um"]
y2 = pm10_inside_data = data_inside.loc[:,"time":"particles 10um"]
plt.plot(y1['particles 10um'], label = 'Outside')
plt.plot(y2['particles 10um'],label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Particles 1.0um')
plt.title('Pm particles 1.0um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1['particles 10um'],bins = 12,  label = 'Outside')
plt.hist(y2['particles 10um'],bins= 12, label = 'Inside')
plt.xlabel('Particles 1.0um')
plt.ylabel('Frequency')
plt.title('Pm particles 1.0um Frequency')
plt.legend()
plt.show()

# %%
y7 = pm25_outside_data = data_outside.loc[:,"time":"particles 25um"]
y8 = pm25_inside_data = data_inside.loc[:,"time":"particles 25um"]
plt.plot(y7['particles 25um'], label = 'Outside')
plt.plot(y8['particles 25um'],label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Particles 25um')
plt.title('Pm particles 25um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y7['particles 25um'], bins = 5,  label = 'Outside')
plt.hist(y8['particles 25um'],bins= 5, label = 'Inside')
plt.xlabel('Particles 25um')
plt.ylabel('Frequency')
plt.title('Pm particles 25um Frequency')
plt.legend()
plt.show()

# %%
y9 = pm25_outside_data = data_outside.loc[:,"time":"particles 50um"]
y10 = pm25_inside_data = data_inside.loc[:,"time":"particles 50um"]
plt.plot(y9['particles 50um'], label = 'Outside')
plt.plot(y10['particles 50um'],label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Particles 50um')
plt.title('Pm particles 50um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y9['particles 50um'], bins = 5,  label = 'Outside')
plt.hist(y10['particles 50um'],bins= 5, label = 'Inside')
plt.xlabel('Particles 50um')
plt.ylabel('Frequency')
plt.title('Pm particles 50um Frequency')
plt.legend()
plt.show()

# %%
y1 = pm25_outside_data = data_outside.loc[:,"time":"particles 100um"]
y2 = pm25_inside_data = data_inside.loc[:,"time":"particles 100um"]
plt.plot(y1['particles 100um'], label = 'Outside')
plt.plot(y2['particles 100um'],label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Particles 100um')
plt.title('Pm particles 100um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1['particles 100um'], bins = 5,  label = 'Outside')
plt.hist(y2['particles 100um'],bins= 5, label = 'Inside')
plt.xlabel('Particles 100um')
plt.ylabel('Frequency')
plt.title('Pm particles 100um Frequency')
plt.legend()
plt.show()

# %%
y1 = pm25_outside_data = data_outside.loc[:,"time":"Temperature C"]
y2 = pm25_inside_data = data_inside.loc[:,"time":"Temperature C"]
plt.plot(y1['Temperature C'], label = 'Outside')
plt.plot(y2['Temperature C'],label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Temperature C')
plt.title('Temperature vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1['Temperature C'], bins = 10,  label = 'Outside')
plt.hist(y2['Temperature C'],bins= 10, label = 'Inside')
plt.xlabel('Temperature C')
plt.ylabel('Frequency')
plt.title('Temperature Frequency')
plt.legend()
plt.show()

# %%
y1 = pm25_outside_data = data_outside.loc[:,"time":"Gas Ohm"]
y2 = pm25_inside_data = data_inside.loc[:,"time":"Gas Ohm"]
plt.plot(y1['Gas Ohm'], label = 'Outside')
plt.plot(y2['Gas Ohm'],label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Gas Ohm')
plt.title('Gas vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1['Gas Ohm'], bins = 10,  label = 'Outside')
plt.hist(y2['Gas Ohm'],bins= 10, label = 'Inside')
plt.xlabel('Gas Ohm')
plt.ylabel('Frequency')
plt.title('Gas Frequency')
plt.legend()
plt.show()

# %%
y1 = pm25_outside_data = data_outside.loc[:,"time":"Humidity %%"]
y2 = pm25_inside_data = data_inside.loc[:,"time":"Humidity %%"]
plt.plot(y1['Humidity %%'], label = 'Outside')
plt.plot(y2['Humidity %%'],label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Humidity %%')
plt.title('Humidity vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1['Humidity %%'], bins = 10,  label = 'Outside')
plt.hist(y2['Humidity %%'],bins= 10, label = 'Inside')
plt.xlabel('Humidity %%')
plt.ylabel('Frequency')
plt.title('Humidity Frequency')
plt.legend()
plt.show()

# %%
y1 = pm25_outside_data = data_outside.loc[:,"time":"Pressure hPa"]
y2 = pm25_inside_data = data_inside.loc[:,"time":"Pressure hPa"]
plt.plot(y1['Pressure hPa'], label = 'Outside')
plt.plot(y2['Pressure hPa'],label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Pressure hPa')
plt.title('Pressure vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1['Pressure hPa'], bins = 5,  label = 'Outside')
plt.hist(y2['Pressure hPa'],bins= 5, label = 'Inside')
plt.xlabel('Pressure hPa')
plt.ylabel('Frequency')
plt.title('Pressure Frequency')
plt.legend()
plt.show()

# %%
y1 = pm25_outside_data = data_outside.loc[:,"time":"Altitude meters"]
y2 = pm25_inside_data = data_inside.loc[:,"time":"Altitude meters"]
plt.plot(y1['Altitude meters'], label = 'Outside')
plt.plot(y2['Altitude meters'],label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Altitude meter')
plt.title('Altitude vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1['Altitude meters'], bins = 10,  label = 'Outside')
plt.hist(y2['Altitude meters'],bins= 10, label = 'Inside')
plt.xlabel('Altitude meters')
plt.ylabel('Frequency')
plt.title('Altitude Frequency')
plt.legend()
plt.show()

# %%
# inside data analysis

inside_data = pd.read_csv('downloads/inside.csv')
inside_column_name_list = list(inside_data.columns)
inside_standard_deviations = []
inside_standard_means = []

for i in range(inside_data.shape[1]):
    inside_column_data = inside_data[inside_column_name_list[i]] 
    inside_standard_deviations.append(np.std(inside_column_data))
    inside_standard_means.append(inside_standard_deviations[i] / np.sqrt(len(inside_column_data)))

# outside data analysis

outside_data = pd.read_csv('downloads/outside.csv')
outside_column_name_list = list(outside_data.columns)
outside_standard_deviations = []
outside_standard_means = []

for i in range(outside_data.shape[1]):
    outside_column_data = outside_data[outside_column_name_list[i]]
    outside_standard_deviations.append(np.std(outside_column_data))
    outside_standard_means.append(outside_standard_deviations[i] / np.sqrt(len(outside_column_data)))

# average standard deviations
average_standard_deviation = np.sqrt(np.array(inside_standard_deviations)**2 + np.array(outside_standard_deviations)**2)

# data comparison 

for i in range(len(outside_standard_means)):
    if ((inside_standard_means[i] <= (3 * average_standard_deviation[i]+ inside_standard_means[i]) and (inside_standard_means[i] >= (inside_standard_means[i] - 3 * average_standard_deviation[i])))):
        inside_deviation = "Yes"
    else:
        inside_deviation = "No"
    if ((outside_standard_means[i] <= (3 * average_standard_deviation[i]+ outside_standard_means[i]) and (outside_standard_means[i] >= (outside_standard_means[i] - 3 * average_standard_deviation[i])))):
        outside_deviation = "Yes"
    else:
        outside_deviation = "No"
    if inside_deviation == "Yes" and outside_deviation == "Yes":
        print(f"{inside_column_name_list[i]}: Both inside and outside data are comparable.")
    elif inside_deviation == "Yes" and outside_deviation == "No":
        print(f"{inside_column_name_list[i]}: Inside data is significantly different from outside data.")
    elif inside_deviation == "No" and outside_deviation == "Yes":
        print(f"{inside_column_name_list[i]}: Outside data is significantly different from inside data.")   
    else:        
        print(f"{inside_column_name_list[i]}: Both inside and outside data are not comparable.")
# Out:
# time: Both inside and outside data are comparable.
# particles 03um: Both inside and outside data are comparable.
# particles 05um: Both inside and outside data are comparable.
# particles 10um: Both inside and outside data are comparable.
# particles 25um: Both inside and outside data are comparable.
# particles 50um: Both inside and outside data are comparable.
# particles 100um: Both inside and outside data are comparable.
# Temperature C: Both inside and outside data are comparable.
# Gas Ohm: Both inside and outside data are comparable.
# Humidity %%: Both inside and outside data are comparable.
# Pressure hPa: Both inside and outside data are comparable.
# Altitude meters: Both inside and outside data are comparable.
