# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_outside = pd.read_csv('downloads/outside2_clean_data.csv')
data_inside = pd.read_csv('downloads/inside.csv')

# %%
outside_data = data_outside.loc[:,"time":"Altitude meters"]
inside_data = data_inside.loc[:,"time":"Altitude meters"]

# %%
y1 = outside_data['particles 03um']
y2 = inside_data['particles 03um'] 
plt.plot(y1, label = 'Outside')
plt.plot(y2,label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Particles 0.3um')
plt.title('Pm particles 0.3um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1,bins = 12,  label = 'Outside')
plt.hist(y2,bins= 12, label = 'Inside')
plt.xlabel('Particles 0.3um')
plt.ylabel('Frequency')
plt.title('Pm particles 0.3um Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['particles 05um']
y2 = inside_data['particles 05um'] 
plt.plot(y1, label = 'Outside')
plt.plot(y2,label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Particles 0.5um')
plt.title('Pm particles 0.5um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1,bins = 12,  label = 'Outside')
plt.hist(y2,bins= 12, label = 'Inside')
plt.xlabel('Particles 0.5um')
plt.ylabel('Frequency')
plt.title('Pm particles 0.5um Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['particles 10um']
y2 = inside_data['particles 10um']
plt.plot(y1, label = 'Outside')
plt.plot(y2, label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Particles 1.0um')
plt.title('Pm particles 1.0um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1,bins = 12,  label = 'Outside')
plt.hist(y2,bins= 12, label = 'Inside')
plt.xlabel('Particles 1.0um')
plt.ylabel('Frequency')
plt.title('Pm particles 1.0um Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['particles 25um']
y2 = inside_data['particles 25um']
plt.plot(y1, label = 'Outside')
plt.plot(y2,label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Particles 25um')
plt.title('Pm particles 25um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1, bins = 5,  label = 'Outside')
plt.hist(y2,bins= 5, label = 'Inside')
plt.xlabel('Particles 25um')
plt.ylabel('Frequency')
plt.title('Pm particles 25um Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['particles 50um']
y2 = inside_data['particles 50um']
plt.plot(y1, label = 'Outside')
plt.plot(y2,label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Particles 50um')
plt.title('Pm particles 50um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1, bins = 5,  label = 'Outside')
plt.hist(y2,bins= 5, label = 'Inside')
plt.xlabel('Particles 50um')
plt.ylabel('Frequency')
plt.title('Pm particles 50um Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['particles 100um']
y2 = inside_data['particles 100um']
plt.plot(y1, label = 'Outside')
plt.plot(y2,label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Particles 100um')
plt.title('Pm particles 100um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1, bins = 5,  label = 'Outside')
plt.hist(y2,bins= 5, label = 'Inside')
plt.xlabel('Particles 100um')
plt.ylabel('Frequency')
plt.title('Pm particles 100um Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['Temperature C']
y2 = inside_data['Temperature C']
plt.plot(y1, label = 'Outside')
plt.plot(y2, label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Temperature C')
plt.title('Temperature vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1, bins = 10,  label = 'Outside')
plt.hist(y2,bins= 10, label = 'Inside')
plt.xlabel('Temperature C')
plt.ylabel('Frequency')
plt.title('Temperature Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['Gas Ohm']
y2 = inside_data['Gas Ohm']
plt.plot(y1, label = 'Outside')
plt.plot(y2,label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Gas Ohm')
plt.title('Gas vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1, bins = 10,  label = 'Outside')
plt.hist(y2,bins= 10, label = 'Inside')
plt.xlabel('Gas Ohm')
plt.ylabel('Frequency')
plt.title('Gas Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['Humidity %%']
y2 = inside_data['Humidity %%']
plt.plot(y1, label = 'Outside')
plt.plot(y2,label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Humidity %%')
plt.title('Humidity vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1, bins = 10,  label = 'Outside')
plt.hist(y2,bins= 10, label = 'Inside')
plt.xlabel('Humidity %%')
plt.ylabel('Frequency')
plt.title('Humidity Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['Pressure hPa']
y2 = inside_data['Pressure hPa']
plt.plot(y1, label = 'Outside')
plt.plot(y2,label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Pressure hPa')
plt.title('Pressure vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1, bins = 5,  label = 'Outside')
plt.hist(y2,bins= 5, label = 'Inside')
plt.xlabel('Pressure hPa')
plt.ylabel('Frequency')
plt.title('Pressure Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['Altitude meters']
y2 = inside_data['Altitude meters']
plt.plot(y1, label = 'Outside')
plt.plot(y2,label = 'Inside')
plt.xlabel('Time')
plt.ylabel('Altitude meter')
plt.title('Altitude vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1, bins = 10,  label = 'Outside')
plt.hist(y2,bins= 10, label = 'Inside')
plt.xlabel('Altitude meters')
plt.ylabel('Frequency')
plt.title('Altitude Frequency')
plt.legend()
plt.show()

# %%
"""
PART 1
"""

# inside data analysis

inside_data = pd.read_csv('downloads/insidespecial - inside.csv')
inside_column_name_list = list(inside_data.columns)
inside_standard_deviations = []
inside_standard_means = []
inside_trial_means = []

for i in range(inside_data.shape[1]):
    inside_column_data = inside_data[inside_column_name_list[i]] 
    inside_standard_deviations.append(np.std(inside_column_data))
    inside_standard_means.append(inside_standard_deviations[i] / np.sqrt(len(inside_column_data)))

    # mean uncertainty for each inside data column
    inside_trial_mean = np.mean(inside_column_data)
    inside_trial_means.append(inside_trial_mean)
    print(f"The mean uncertainty for {inside_column_name_list[i]} (for our inside data) is {inside_trial_mean}")

# outside data analysis

outside_data = pd.read_csv('downloads/outside2special - outside2.csv')
outside_column_name_list = list(outside_data.columns)
outside_standard_deviations = []
outside_standard_means = []
outside_trial_means = []

for i in range(outside_data.shape[1]-1):
    outside_column_data = outside_data[outside_column_name_list[i]]
    outside_standard_deviations.append(np.std(outside_column_data))
    outside_standard_means.append(outside_standard_deviations[i] / np.sqrt(len(outside_column_data)))

    # mean uncertainty for outside
    outside_trial_mean = np.mean(outside_column_data)
    outside_trial_means.append(outside_trial_mean)
    print(f"The mean uncertainty for {outside_column_name_list[i]} (for our outside data) is {outside_trial_mean}")


# average standard deviations
average_standard_deviation = np.sqrt(np.array(inside_standard_deviations)**2 + np.array(outside_standard_deviations)**2)

    
# data comparison 
for i in range(len(outside_standard_means)):
    if ((inside_standard_means[i] <= (3 * average_standard_deviation[i]+ inside_standard_means[i]) and (inside_standard_means[i] >= (inside_standard_means[i] - 3 * average_standard_deviation[i])))):
        inside_deviation = "Yes"
    else:
        inside_deviation = "No"
    if ((outside_standard_means[i] <= (3 * average_standard_deviation[i]+ outside_standard_means[i]) and (outside_standard_means[i] >= (outside_standard_means[i] - 3 * average_standard_deviation[i])))):
        outside_deviation = "Yes"
    else:
        outside_deviation = "No"
    if inside_deviation == "Yes" and outside_deviation == "Yes":
        print(f"{inside_column_name_list[i]}: Both inside and outside data are comparable.")
    elif inside_deviation == "Yes" and outside_deviation == "No":
        print(f"{inside_column_name_list[i]}: Inside data is significantly different from outside data.")
    elif inside_deviation == "No" and outside_deviation == "Yes":
        print(f"{inside_column_name_list[i]}: Outside data is significantly different from inside data.")   
    else:        
        print(f"{inside_column_name_list[i]}: Both inside and outside data are not comparable.")

for i in range(len(outside_standard_means)):
    # within or outside standard deviations
    # inside
    within_inside_calculation = inside_trial_means[i]/np.sqrt(inside_column_data)
    print(f"sigma sub mu, inside: {within_inside_calculation}")
    
    # outside
    within_outside_calculation = outside_trial_means[i]/np.sqrt(outside_column_data)
    print(f"sigma sub mu, outside: {within_outside_calculation}")
    
    # difference
    within_differences = within_inside_calculation - within_outside_calculation
    print(f"difference: {within_differences}")
    
    # comparison 
    if sum(within_inside_calculation) > sum(within_outside_calculation):
        comparison = sum(within_differences/within_inside_calculation)
    else:
        comparison = sum(within_differences/within_outside_calculation)
    
    # standard deviations away
    if comparison < 2.58:
        print(f"The {inside_column_name_list[i]} data for both inside and outside are within 1% of each other, indicating that the inside and outside data are comparable.") 
    else:
        print(f"The {inside_column_name_list[i]} data for both inside and outside are outside 1% of each other, indicating that the inside and outside data are not comparable.")
        print("As our increased amount of data makes differences in said data more pronounced, we believe that we have collected enough data to indicate whether it can be represented by a Gaussian distribution (which, it can't). This may be due to human error when changing locations to collect data, or due to insensitivity within our sensors.")


"""
PART 2
"""



# inside data analysis

inside_data = pd.read_csv('downloads/insidespecial - inside.csv')
inside_column_name_list = list(inside_data.columns)
inside_standard_deviations = []
inside_standard_means = []
inside_trial_means = []

for i in range(inside_data.shape[1]):
    inside_column_data = inside_data[inside_column_name_list[i]] 
    inside_standard_deviations.append(np.std(inside_column_data))
    inside_standard_means.append(inside_standard_deviations[i] / np.sqrt(len(inside_column_data)))

    # mean uncertainty for each inside data column
    inside_trial_mean = np.mean(inside_column_data)
    inside_trial_means.append(inside_trial_mean)
    print(f"The mean uncertainty for {inside_column_name_list[i]} (for our inside data) is {inside_trial_mean}")

# other group inside data analysis

other_inside_data = pd.read_csv('downloads/inside_5min - inside_5min.csv')
other_inside_column_name_list = list(other_inside_data.columns)
other_inside_standard_deviations = []
other_inside_standard_means = []
other_inside_trial_means = []

for i in range(other_inside_data.shape[1]):
    other_inside_column_data = other_inside_data[other_inside_column_name_list[i]]
    other_inside_standard_deviations.append(np.std(other_inside_column_data))
    other_inside_standard_means.append(other_inside_standard_deviations[i] / np.sqrt(len(other_inside_column_data)))

    # mean uncertainty for each inside data column
    other_inside_trial_mean = np.mean(other_inside_column_data)
    other_inside_trial_means.append(other_inside_trial_mean)
    print(f"The mean uncertainty for {inside_column_name_list[i]} (for the other group's inside data) is {other_inside_trial_mean}")

# average standard deviations
average_standard_deviation = np.sqrt(np.array(inside_standard_deviations)**2 + np.array(other_inside_standard_deviations)**2)

# data comparison 
for i in range(len(other_inside_standard_means)):
    if ((inside_standard_means[i] <= (3 * average_standard_deviation[i]+ inside_standard_means[i]) and (inside_standard_means[i] >= (inside_standard_means[i] - 3 * average_standard_deviation[i])))):
        inside_deviation = "Yes"
    else:
        inside_deviation = "No"
    if ((other_inside_standard_means[i] <= (3 * average_standard_deviation[i]+ other_inside_standard_means[i]) and (other_inside_standard_means[i] >= (other_inside_standard_means[i] - 3 * average_standard_deviation[i])))):
        other_inside_deviation = "Yes"
    else:
        other_inside_deviation = "No"
    if inside_deviation == "Yes" and other_inside_deviation == "Yes":
        print(f"{inside_column_name_list[i]}: Both inside and other group's inside data are comparable.")
    elif inside_deviation == "Yes" and other_inside_deviation == "No":
        print(f"{inside_column_name_list[i]}: Inside data is significantly different from other group's inside data.")
    elif inside_deviation == "No" and other_inside_deviation == "Yes":
        print(f"{inside_column_name_list[i]}: Other group's inside data is significantly different from inside data.")   
    else:        
        print(f"{inside_column_name_list[i]}: Both inside and other group's inside data are not comparable.")

for i in range(len(inside_standard_means)):
    # within or outside standard deviations
    # inside
    within_inside_calculation = inside_trial_means[i]/np.sqrt(inside_column_data)
    print(f"sigma sub mu, inside: {within_inside_calculation}")
    
    # other inside
    within_other_inside_calculation = other_inside_trial_means[i]/np.sqrt(other_inside_trials_count)
    print(f"sigma sub mu, other group's inside: {within_other_inside_calculation}")
    
    # difference
    within_differences = within_inside_calculation - within_other_inside_calculation
    print(f"difference: {within_differences}")
    
    # comparison 
    if within_inside_calculation > within_other_inside_calculation:
        comparison = within_differences/within_inside_calculation
    else:
        comparison = within_differences/within_other_inside_calculation
    
    # standard deviations away
    if comparison < 2.58:
        print(f"The {inside_column_name_list[i]} data for both inside and the other group's inside are within 1% of each other, indicating that the inside and other inside data are comparable.") 
    else:
        print(f"The {inside_column_name_list[i]} data for both inside and the other group's inside are outside 1% of each other, indicating that the inside and other inside data are not comparable.")
        print("As our increased amount of data makes differences in said data more pronounced, we believe that we have collected enough data to indicate whether it can be represented by a Gaussian distribution (which, it can't). This may be due to human error when changing locations to collect data, or due to insensitivity within our sensors.")


# outside data analysis

outside_data = pd.read_csv('downloads/outside2special - outside2.csv')
outside_column_name_list = list(outside_data.columns)
outside_standard_deviations = []
outside_standard_means = []
outside_trial_means = []

for i in range(outside_data.shape[1]):
    outside_column_data = outside_data[outside_column_name_list[i]] 
    outside_standard_deviations.append(np.std(outside_column_data))
    outside_standard_means.append(outside_standard_deviations[i] / np.sqrt(len(outside_column_data)))

    # mean uncertainty for outside
    outside_trial_mean = np.mean(outside_column_data)
    outside_trial_means.append(outside_trial_mean)
    print(f"The mean uncertainty for {outside_column_name_list[i]} (for our outside data) is {outside_trial_mean}")

# other group outside data analysis

other_outside_data = pd.read_csv('downloads/double_data_outside_5min - double_data_outside_5min.csv')
other_outside_column_name_list = list(other_outside_data.columns)
other_outside_standard_deviations = []
other_outside_standard_means = []
other_outside_trial_means

for i in range(other_outside_data.shape[1]):
    other_outside_column_data = other_outside_data[other_outside_column_name_list[i]]
    other_outside_standard_deviations.append(np.std(other_outside_column_data))
    other_outside_standard_means.append(other_outside_standard_deviations[i] / np.sqrt(len(other_outside_column_data)))

    # mean uncertainty for outside
    other_outside_trial_mean = np.mean(other_outside_column_data)
    other_outside_trial_means.append(other_outside_trial_mean)
    print(f"The mean uncertainty for {outside_column_name_list[i]} (for our outside data) is {other_outside_trial_mean}")

# average standard deviations
average_standard_deviation = np.sqrt(np.array(outside_standard_deviations)**2 + np.array(other_outside_standard_deviations)**2)

# data comparison 
for i in range(len(other_outside_standard_means)):
    if ((outside_standard_means[i] <= (3 * average_standard_deviation[i]+ outside_standard_means[i]) and (outside_standard_means[i] >= (outside_standard_means[i] - 3 * average_standard_deviation[i])))):
        outside_deviation = "Yes"
    else:
        outside_deviation = "No"
    if ((other_outside_standard_means[i] <= (3 * average_standard_deviation[i]+ other_outside_standard_means[i]) and (other_outside_standard_means[i] >= (other_outside_standard_means[i] - 3 * average_standard_deviation[i])))):
        other_outside_deviation = "Yes"
    else:
        other_outside_deviation = "No"
    if outside_deviation == "Yes" and other_outside_deviation == "Yes":
        print(f"{outside_column_name_list[i]}: Both outside and other group's outside data are comparable.")
    elif outside_deviation == "Yes" and other_outside_deviation == "No":
        print(f"{outside_column_name_list[i]}: Inside data is significantly different from other group's outside data.")
    elif outside_deviation == "No" and other_outside_deviation == "Yes":
        print(f"{outside_column_name_list[i]}: Other group's outside data is significantly different from outside data.")   
    else:        
        print(f"{outside_column_name_list[i]}: Both outside and other group's outside data are not comparable.")

for i in range(len(outside_standard_means)):
    # within or outside standard deviations
    # outside
    within_outside_calculation = outside_trial_means[i]/np.sqrt(outside_column_data)
    print(f"sigma sub mu, outside: {within_outside_calculation}")
    
    # other outside
    within_other_outside_calculation = other_outside_trial_means[i]/np.sqrt(other_outside_trials_count)
    print(f"sigma sub mu, other group's outside: {within_other_outside_calculation}")
    
    # difference
    within_differences = within_outside_calculation - within_other_outside_calculation
    print(f"difference: {within_differences}")
    
    # comparison 
    if within_outside_calculation > within_other_outside_calculation:
        comparison = within_differences/within_outside_calculation
    else:
        comparison = within_differences/within_other_outside_calculation
    
    # standard deviations away
    if comparison < 2.58:
        print(f"The {outside_column_name_list[i]} data for both outside and the other group's outside are within 1% of each other, indicating that the outside and the other outside data are comparable.") 
    else:
        print(f"The {outside_column_name_list[i]} data for both outside and the other group's outside are outside 1% of each other, indicating that the outside and the other outside data are not comparable.")
        print("As our increased amount of data makes differences in said data more pronounced, we believe that we have collected enough data to indicate whether it can be represented by a Gaussian distribution (which, it can't). This may be due to human error when changing locations to collect data, or due to insensitivity within our sensors.")
# Out:
# The mean uncertainty for particles 03um (for our inside data) is 263.45454545454544
# The mean uncertainty for particles 05um (for our inside data) is 71.62626262626263
# The mean uncertainty for particles 10um (for our inside data) is 13.636363636363637
# The mean uncertainty for particles 25um (for our inside data) is 1.0606060606060606
# The mean uncertainty for particles 50um (for our inside data) is 0.0
# The mean uncertainty for particles 100um (for our inside data) is 0.0
# The mean uncertainty for Temperature C (for our inside data) is 22.422489348148147
# The mean uncertainty for Gas Ohm (for our inside data) is 279313.80134680134
# The mean uncertainty for Humidity %% (for our inside data) is 36.734932413804714
# The mean uncertainty for Pressure hPa (for our inside data) is 1003.0872822663298
# The mean uncertainty for Altitude meters (for our inside data) is 86.04428930397306
# The mean uncertainty for time (for our outside data) is 1772058808.6060605
# ...

# %%
len(inside_standard_deviations)
#len(outside_standard_deviations)
# Out:
# 11

# %%
data_outside_clean = pd.read_csv('downloads/outside2_clean_data.csv')
data_alley = pd.read_csv('downloads/outside_alley_clean_data.csv')

# %%
outside_data = data_outside_clean.loc[:,"time":"Altitude meters"]
alley_data = data_alley.loc[:,"time":"Altitude meters"]

# %%
y1 = outside_data['particles 03um']
y2 = alley_data['particles 03um'] 
plt.plot(y1, label = 'Soda Hall Rooftop')
plt.plot(y2,label = "Alleyway")
plt.xlabel('Time')
plt.ylabel('Particles 0.3um')
plt.title('Pm particles 0.3um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1,bins = 12,  label = 'Soda Hall Rooftop')
plt.hist(y2,bins= 12, label = 'Alleyway')
plt.xlabel('Particles 0.3um')
plt.ylabel('Frequency')
plt.title('Pm particles 0.3um Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['particles 05um']
y2 = alley_data['particles 05um'] 
plt.plot(y1, label = 'Soda Hall Rooftop')
plt.plot(y2,label = 'Alleyway')
plt.xlabel('Time')
plt.ylabel('Particles 0.5um')
plt.title('Pm particles 0.5um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1,bins = 12,  label = 'Soda Hall Rooftop')
plt.hist(y2,bins= 12, label = 'Alleyway')
plt.xlabel('Particles 0.5um')
plt.ylabel('Frequency')
plt.title('Pm particles 0.5um Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['particles 10um']
y2 = alley_data['particles 10um']
plt.plot(y1, label = 'Soda Hall Rooftop')
plt.plot(y2, label = 'Alleyway')
plt.xlabel('Time')
plt.ylabel('Particles 1.0um')
plt.title('Pm particles 1.0um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1,bins = 12,  label = 'Soda Hall Rooftop')
plt.hist(y2,bins= 12, label = 'Alleyway')
plt.xlabel('Particles 1.0um')
plt.ylabel('Frequency')
plt.title('Pm particles 1.0um Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['particles 25um']
y2 = alley_data['particles 25um']
plt.plot(y1, label = 'Soda Hall Rooftop')
plt.plot(y2,label = 'Alleyway')
plt.xlabel('Time')
plt.ylabel('Particles 25um')
plt.title('Pm particles 25um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1, bins = 5,  label = 'Soda Hall Rooftop')
plt.hist(y2,bins= 5, label = 'Alleyway')
plt.xlabel('Particles 25um')
plt.ylabel('Frequency')
plt.title('Pm particles 25um Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['particles 50um']
y2 = alley_data['particles 50um']
plt.plot(y1, label = 'Soda Hall Rooftop')
plt.plot(y2,label = 'Alleyway')
plt.xlabel('Time')
plt.ylabel('Particles 50um')
plt.title('Pm particles 50um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1, bins = 5,  label = 'Soda Hall Rooftop')
plt.hist(y2,bins= 5, label = 'Alleyway')
plt.xlabel('Particles 50um')
plt.ylabel('Frequency')
plt.title('Pm particles 50um Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['particles 100um']
y2 = alley_data['particles 100um']
plt.plot(y1, label = 'Soda Hall Rooftop')
plt.plot(y2,label = 'Alleyway')
plt.xlabel('Time')
plt.ylabel('Particles 100um')
plt.title('Pm particles 100um vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1, bins = 5,  label = 'Soda Hall Rooftop')
plt.hist(y2,bins= 5, label = 'Alleyway')
plt.xlabel('Particles 100um')
plt.ylabel('Frequency')
plt.title('Pm particles 100um Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['Temperature C']
y2 = alley_data['Temperature C']
plt.plot(y1, label = 'Soda Hall Rooftop')
plt.plot(y2, label = 'Alleyway')
plt.xlabel('Time')
plt.ylabel('Temperature C')
plt.title('Temperature vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1, bins = 10,  label = 'Soda Hall Rooftop')
plt.hist(y2,bins= 10, label = 'Alleyway')
plt.xlabel('Temperature C')
plt.ylabel('Frequency')
plt.title('Temperature Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['Gas Ohm']
y2 = alley_data['Gas Ohm']
plt.plot(y1, label = 'Soda Hall Rooftop')
plt.plot(y2,label = 'Alleyway')
plt.xlabel('Time')
plt.ylabel('Gas Ohm')
plt.title('Gas vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1, bins = 10,  label = 'Soda Hall Rooftop')
plt.hist(y2,bins= 10, label = 'Alleyway')
plt.xlabel('Gas Ohm')
plt.ylabel('Frequency')
plt.title('Gas Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['Humidity %%']
y2 = alley_data['Humidity %%']
plt.plot(y1, label = 'Soda Hall Rooftop')
plt.plot(y2,label = 'Alleyway')
plt.xlabel('Time')
plt.ylabel('Humidity %%')
plt.title('Humidity vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1, bins = 10,  label = 'Soda Hall Rooftop')
plt.hist(y2,bins= 10, label = 'Alleyway')
plt.xlabel('Humidity %%')
plt.ylabel('Frequency')
plt.title('Humidity Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['Pressure hPa']
y2 = alley_data['Pressure hPa']
plt.plot(y1, label = 'Soda Hall Rooftop')
plt.plot(y2,label = 'Alleyway')
plt.xlabel('Time')
plt.ylabel('Pressure hPa')
plt.title('Pressure vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1, bins = 5,  label = 'Soda Hall Rooftop')
plt.hist(y2,bins= 5, label = 'Alleyway')
plt.xlabel('Pressure hPa')
plt.ylabel('Frequency')
plt.title('Pressure Frequency')
plt.legend()
plt.show()

# %%
y1 = outside_data['Altitude meters']
y2 = alley_data['Altitude meters']
plt.plot(y1, label = 'Soda Hall Rooftop')
plt.plot(y2,label = 'Alleyway')
plt.xlabel('Time')
plt.ylabel('Altitude meter')
plt.title('Altitude vs Time')
plt.legend()
plt.show()

# %%
plt.hist(y1, bins = 10,  label = 'Soda Hall Rooftop')
plt.hist(y2,bins= 10, label = 'Alleyway')
plt.xlabel('Altitude meters')
plt.ylabel('Frequency')
plt.title('Altitude Frequency')
plt.legend()
plt.show()

# %%
# inside data analysis

alley_data = pd.read_csv('downloads/outside_alley_clean_data.csv')
inside_column_name_list = alley_column_name_list = list(alley_data.columns)
inside_standard_deviations= alley_standard_deviations = []
inside_standard_means = alley_standard_means = []

for i in range(alley_data.shape[1]):
    alley_column_data = alley_data[alley_column_name_list[i]] 
    alley_standard_deviations.append(np.std(alley_column_data))
    alley_standard_means.append(alley_standard_deviations[i] / np.sqrt(len(alley_column_data)))

# outside data analysis

outside_data = pd.read_csv('downloads/outside2.csv')
outside_column_name_list = list(outside_data.columns)
outside_standard_deviations = []
outside_standard_means = []

for i in range(outside_data.shape[1]):
    outside_column_data = outside_data[outside_column_name_list[i]]
    outside_standard_deviations.append(np.std(outside_column_data))
    outside_standard_means.append(outside_standard_deviations[i] / np.sqrt(len(outside_column_data)))

# average standard deviations
average_standard_deviation = np.sqrt(np.array(alley_standard_deviations)**2 + np.array(outside_standard_deviations)**2)

# data comparison 

for i in range(len(outside_standard_means)):
    if ((inside_standard_means[i] <= (3 * average_standard_deviation[i]+ inside_standard_means[i]) and (inside_standard_means[i] >= (inside_standard_means[i] - 3 * average_standard_deviation[i])))):
        inside_deviation = "Yes"
    else:
        inside_deviation = "No"
    if ((outside_standard_means[i] <= (3 * average_standard_deviation[i]+ outside_standard_means[i]) and (outside_standard_means[i] >= (outside_standard_means[i] - 3 * average_standard_deviation[i])))):
        outside_deviation = "Yes"
    else:
        outside_deviation = "No"
    if inside_deviation == "Yes" and outside_deviation == "Yes":
        print(f"{inside_column_name_list[i]}: Both alley and outside data are comparable.")
    elif inside_deviation == "Yes" and outside_deviation == "No":
        print(f"{inside_column_name_list[i]}: Alley data is significantly different from outside data.")
    elif inside_deviation == "No" and outside_deviation == "Yes":
        print(f"{inside_column_name_list[i]}: Outside data is significantly different from alley data.")   
    else:        
        print(f"{inside_column_name_list[i]}: Both alley and outside data are not comparable.")
# Out:
# time: Both alley and outside data are comparable.
# particles 03um: Both alley and outside data are comparable.
# particles 05um: Both alley and outside data are comparable.
# particles 10um: Both alley and outside data are comparable.
# particles 25um: Both alley and outside data are comparable.
# particles 50um: Both alley and outside data are comparable.
# particles 100um: Both alley and outside data are comparable.
# Temperature C: Both alley and outside data are comparable.
# Gas Ohm: Both alley and outside data are comparable.
# Humidity %%: Both alley and outside data are comparable.
# Pressure hPa: Both alley and outside data are comparable.
# Altitude meters: Both alley and outside data are comparable.

# %%
data_outside2 = pd.read_csv('downloads/outside2_clean_data.csv')
data_inside3 = pd.read_csv('downloads/outside_alley_clean_data.csv')

# %%
outside2_data = data_outside2.loc[:,"time":"Altitude meters"]
outside3_data = data_inside3.loc[:,"time":"Altitude meters"]

# %%
y1 = outside2_data['Temperature C']
y2 = outside3_data['Temperature C']
y3 = outside2_data['Humidity %%']
y4 = outside3_data['Humidity %%']

fig = plt.figure(figsize=(12,8))

# Plot 1 (1 row, 2 columns, plot index 1)
ax1 = plt.subplot(1, 3, 1)
ax1.plot(y1, label = 'Soda Hall Roof - Temp')
ax1.plot(y2, label = 'Alleyway - Temp')
ax1.set_title("Temperature Comparison") 
ax1.set_xlabel('Time')
ax1.set_ylabel('Temperature C')
ax1.legend(loc='best')

# Plot 2 (1 row, 2 columns, plot index 2)
ax2 = plt.subplot(1, 3, 2) # or plt.subplot(122)
ax2.plot(y3, label = 'Soda Hall Roof - Humindity')
ax2.plot(y4, label = 'Alleyway - Humindity')
ax2.set_title("Humidity Comparison")
ax2.set_xlabel('Time')
ax2.set_ylabel('Humidity')
ax2.legend(loc='best')


ax3 = plt.subplot(1, 3, 3) # 
ax3.plot(y1,y3, label = 'Soda Hall Roof')
ax3.plot(y2,y4, label = 'Alleyway')
ax3.set_title("Temp vs Humidity")
ax3.set_xlabel('Temp')
ax3.set_ylabel('Humidity')
ax3.legend(loc='best')

plt.show()

# %%
#What does this plot show? Are temperature and humidity correlated? How would you quantify this?
#

# %%
y1 = outside2_data['Temperature C']
y2 = outside3_data['Temperature C']
y3 = outside2_data['Pressure hPa']
y4 = outside3_data['Pressure hPa']

fig = plt.figure(figsize=(12,8))

# Plot 1 (1 row, 2 columns, plot index 1)
ax1 = plt.subplot(1, 3, 1)
ax1.plot(y1, label = 'Soda Hall Roof - Temp')
ax1.plot(y2, label = 'Alleyway - Temp')
ax1.set_title("Temperature Comparison") 
ax1.set_xlabel('Time')
ax1.set_ylabel('Temperature C')
ax1.legend(loc='best')

# Plot 2 (1 row, 2 columns, plot index 2)
ax2 = plt.subplot(1, 3, 2) # or plt.subplot(122)
ax2.plot(y3, label = 'Soda Hall Roof - Pressure')
ax2.plot(y4, label = 'Alleyway - Pressure')
ax2.set_title("Pressure Comparison")
ax2.set_xlabel('Time')
ax2.set_ylabel('Pressure')
ax2.legend(loc='best')


ax3 = plt.subplot(1, 3, 3) # 
ax3.plot(y1,y3, label = 'Soda Hall Roof')
ax3.plot(y2,y4, label = 'Alleyway')
ax3.set_title("Temp vs Pressure")
ax3.set_xlabel('Temp')
ax3.set_ylabel('Pressure')
ax3.legend(loc='best')

plt.show()

# %%
y1 = outside2_data['Temperature C']
y2 = outside3_data['Temperature C']
y3 = outside2_data['Gas Ohm']
y4 = outside3_data['Gas Ohm']

fig = plt.figure(figsize=(12,8))

# Plot 1 (1 row, 2 columns, plot index 1)
ax1 = plt.subplot(1, 3, 1)
ax1.plot(y1, label = 'Soda Hall Roof - Temp')
ax1.plot(y2, label = 'Alleyway - Temp')
ax1.set_title("Temperature Comparison") 
ax1.set_xlabel('Time')
ax1.set_ylabel('Temperature C')
ax1.legend(loc='best')

# Plot 2 (1 row, 2 columns, plot index 2)
ax2 = plt.subplot(1, 3, 2) # or plt.subplot(122)
ax2.plot(y3, label = 'Soda Hall Roof - Gas')
ax2.plot(y4, label = 'Alleyway - Gas')
ax2.set_title("Gas Comparison")
ax2.set_xlabel('Time')
ax2.set_ylabel('Gas Ohm')
ax2.legend(loc='best')


ax3 = plt.subplot(1, 3, 3) # 
ax3.plot(y1,y3, label = 'Soda Hall Roof')
ax3.plot(y2,y4, label = 'Alleyway')
ax3.set_title("Temp vs Gas")
ax3.set_xlabel('Temp')
ax3.set_ylabel('Gas')
ax3.legend(loc='best')

plt.show()

# %%
y1 = outside2_data['Temperature C']
y2 = outside3_data['Temperature C']
y3 = outside2_data['Altitude meters']
y4 = outside3_data['Altitude meters']

fig = plt.figure(figsize=(12,8))

# Plot 1 (1 row, 2 columns, plot index 1)
ax1 = plt.subplot(1, 3, 1)
ax1.plot(y1, label = 'Soda Hall Roof - Temp')
ax1.plot(y2, label = 'Alleyway - Temp')
ax1.set_title("Temperature Comparison") 
ax1.set_xlabel('Time')
ax1.set_ylabel('Temperature C')
ax1.legend(loc='best')

# Plot 2 (1 row, 2 columns, plot index 2)
ax2 = plt.subplot(1, 3, 2) # or plt.subplot(122)
ax2.plot(y3, label = 'Soda Hall Roof - Altitude')
ax2.plot(y4, label = 'Alleyway - Altitude')
ax2.set_title("Altitude Comparison")
ax2.set_xlabel('Time')
ax2.set_ylabel('Altitude meters')
ax2.legend(loc='best')


ax3 = plt.subplot(1, 3, 3) # 
ax3.plot(y1,y3, label = 'Soda Hall Roof')
ax3.plot(y2,y4, label = 'Alleyway')
ax3.set_title("Temp vs Altitude")
ax3.set_xlabel('Temp')
ax3.set_ylabel('Altitude')
ax3.legend(loc='best')

plt.show()

# %%
y1 = outside2_data['Temperature C']
y2 = outside3_data['Temperature C']
y3 = outside2_data['particles 03um']
y4 = outside3_data['particles 03um']

fig = plt.figure(figsize=(12,8))

# Plot 1 (1 row, 2 columns, plot index 1)
ax1 = plt.subplot(1, 3, 1)
ax1.plot(y1, label = 'Soda Hall Roof - Temp')
ax1.plot(y2, label = 'Alleyway - Temp')
ax1.set_title("Temperature Comparison") 
ax1.set_xlabel('Time')
ax1.set_ylabel('Temperature C')
ax1.legend(loc='best')

# Plot 2 (1 row, 2 columns, plot index 2)
ax2 = plt.subplot(1, 3, 2) # or plt.subplot(122)
ax2.plot(y3, label = 'Soda Hall Roof - particles 03um')
ax2.plot(y4, label = 'Alleyway - particles 03um')
ax2.set_title("Particles 03um Comparison")
ax2.set_xlabel('Time')
ax2.set_ylabel('Particles 03um')
ax2.legend(loc='best')


ax3 = plt.subplot(1, 3, 3) # 
ax3.plot(y1,y3, label = 'Soda Hall Roof')
ax3.plot(y2,y4, label = 'Alleyway')
ax3.set_title("Temp vs Particles 03um")
ax3.set_xlabel('Temp')
ax3.set_ylabel('Altitude')
ax3.legend(loc='best')

plt.show()

# %%
y1 = outside2_data['Temperature C']
y2 = outside3_data['Temperature C']
y3 = outside2_data['particles 05um']
y4 = outside3_data['particles 05um']

fig = plt.figure(figsize=(12,8))

# Plot 1 (1 row, 2 columns, plot index 1)
ax1 = plt.subplot(1, 3, 1)
ax1.plot(y1, label = 'Soda Hall Roof - Temp')
ax1.plot(y2, label = 'Alleyway - Temp')
ax1.set_title("Temperature Comparison") 
ax1.set_xlabel('Time')
ax1.set_ylabel('Temperature C')
ax1.legend(loc='best')

# Plot 2 (1 row, 2 columns, plot index 2)
ax2 = plt.subplot(1, 3, 2) # or plt.subplot(122)
ax2.plot(y3, label = 'Soda Hall Roof - particles 05um')
ax2.plot(y4, label = 'Alleyway - particles 05um')
ax2.set_title("Particles 05um Comparison")
ax2.set_xlabel('Time')
ax2.set_ylabel('Particles 05um')
ax2.legend(loc='best')


ax3 = plt.subplot(1, 3, 3) # 
ax3.plot(y1,y3, label = 'Soda Hall Roof')
ax3.plot(y2,y4, label = 'Alleyway')
ax3.set_title("Temp vs Particles 05um")
ax3.set_xlabel('Temp')
ax3.set_ylabel('Altitude')
ax3.legend(loc='best')

plt.show()

# %%
alley_data
# Out:
#            time  particles 03um  particles 05um  particles 10um  \
# 0    1772060197             120              34               8
# 1    1772060198             150              42               8
# 2    1772060199             150              42               8
# 3    1772060200             150              42               8
# 4    1772060201             138              40               8
# ..          ...             ...             ...             ...
# 295  1772060545             246              68              14
# 296  1772060547             246              68              14
# 297  1772060548             246              68              14
# 298  1772060549             216              60              14
# 299  1772060550             216              60              14
#
#      particles 25um  particles 50um  particles 100um  Temperature C  Gas Ohm  \
# 0                 2               0                0      23.396992    64244
# ...

# %%
y1 = outside2_data['Temperature C']
y2 = outside3_data['Temperature C']
y3 = outside2_data['particles 10um']
y4 = outside3_data['particles 10um']

fig = plt.figure(figsize=(12,8))

# Plot 1 (1 row, 2 columns, plot index 1)
ax1 = plt.subplot(1, 3, 1)
ax1.plot(y1, label = 'Soda Hall Roof - Temp')
ax1.plot(y2, label = 'Alleyway - Temp')
ax1.set_title("Temperature Comparison") 
ax1.set_xlabel('Time')
ax1.set_ylabel('Temperature C')
ax1.legend(loc='best')

# Plot 2 (1 row, 2 columns, plot index 2)
ax2 = plt.subplot(1, 3, 2) # or plt.subplot(122)
ax2.plot(y3, label = 'Soda Hall Roof - particles 10um')
ax2.plot(y4, label = 'Alleyway - particles 10um')
ax2.set_title("Particles 10um Comparison")
ax2.set_xlabel('Time')
ax2.set_ylabel('Particles 10um')
ax2.legend(loc='best')


ax3 = plt.subplot(1, 3, 3) # 
ax3.plot(y1,y3, label = 'Soda Hall Roof')
ax3.plot(y2,y4, label = 'Alleyway')
ax3.set_title("Temp vs Particles 10um")
ax3.set_xlabel('Temp')
ax3.set_ylabel('Altitude')
ax3.legend(loc='best')

plt.show()

# %%
y1 = outside2_data['Temperature C']
y2 = outside3_data['Temperature C']
y3 = outside2_data['particles 25um']
y4 = outside3_data['particles 25um']

fig = plt.figure(figsize=(12,8))

# Plot 1 (1 row, 2 columns, plot index 1)
ax1 = plt.subplot(1, 3, 1)
ax1.plot(y1, label = 'Soda Hall Roof - Temp')
ax1.plot(y2, label = 'Alleyway - Temp')
ax1.set_title("Temperature Comparison") 
ax1.set_xlabel('Time')
ax1.set_ylabel('Temperature C')
ax1.legend(loc='best')

# Plot 2 (1 row, 2 columns, plot index 2)
ax2 = plt.subplot(1, 3, 2) # or plt.subplot(122)
ax2.plot(y3, label = 'Soda Hall Roof - particles 25um')
ax2.plot(y4, label = 'Alleyway - particles 25um')
ax2.set_title("Particles 25um Comparison")
ax2.set_xlabel('Time')
ax2.set_ylabel('Particles 25um')
ax2.legend(loc='best')


ax3 = plt.subplot(1, 3, 3) # 
ax3.plot(y1,y3, label = 'Soda Hall Roof')
ax3.plot(y2,y4, label = 'Alleyway')
ax3.set_title("Temp vs Particles 25um")
ax3.set_xlabel('Temp')
ax3.set_ylabel('Altitude')
ax3.legend(loc='best')

plt.show()

# %%
y1 = outside2_data['Temperature C']
y2 = outside3_data['Temperature C']
y3 = outside2_data['particles 50um']
y4 = outside3_data['particles 50um']

fig = plt.figure(figsize=(12,8))

# Plot 1 (1 row, 2 columns, plot index 1)
ax1 = plt.subplot(1, 3, 1)
ax1.plot(y1, label = 'Soda Hall Roof - Temp')
ax1.plot(y2, label = 'Alleyway - Temp')
ax1.set_title("Temperature Comparison") 
ax1.set_xlabel('Time')
ax1.set_ylabel('Temperature C')
ax1.legend(loc='best')

# Plot 2 (1 row, 2 columns, plot index 2)
ax2 = plt.subplot(1, 3, 2) # or plt.subplot(122)
ax2.plot(y3, label = 'Soda Hall Roof - particles 50um')
ax2.plot(y4, label = 'Alleyway - particles 50um')
ax2.set_title("Particles 50um Comparison")
ax2.set_xlabel('Time')
ax2.set_ylabel('Particles 50um')
ax2.legend(loc='best')


ax3 = plt.subplot(1, 3, 3) # 
ax3.plot(y1,y3, label = 'Soda Hall Roof')
ax3.plot(y2,y4, label = 'Alleyway')
ax3.set_title("Temp vs Particles 50um")
ax3.set_xlabel('Temp')
ax3.set_ylabel('Altitude')
ax3.legend(loc='best')

plt.show()

# %%
y1 = outside2_data['Temperature C']
y2 = outside3_data['Temperature C']
y3 = outside2_data['particles 100um']
y4 = outside3_data['particles 100um']

fig = plt.figure(figsize=(12,8))

# Plot 1 (1 row, 2 columns, plot index 1)
ax1 = plt.subplot(1, 3, 1)
ax1.plot(y1, label = 'Soda Hall Roof - Temp')
ax1.plot(y2, label = 'Alleyway - Temp')
ax1.set_title("Temperature Comparison") 
ax1.set_xlabel('Time')
ax1.set_ylabel('Temperature C')
ax1.legend(loc='best')

# Plot 2 (1 row, 2 columns, plot index 2)
ax2 = plt.subplot(1, 3, 2) # or plt.subplot(122)
ax2.plot(y3, label = 'Soda Hall Roof - particles 100um')
ax2.plot(y4, label = 'Alleyway - particles 100um')
ax2.set_title("Particles 100um Comparison")
ax2.set_xlabel('Time')
ax2.set_ylabel('Particles 100um')
ax2.legend(loc='best')


ax3 = plt.subplot(1, 3, 3) # 
ax3.plot(y1,y3, label = 'Soda Hall Roof')
ax3.plot(y2,y4, label = 'Alleyway')
ax3.set_title("Temp vs Particles 100um")
ax3.set_xlabel('Temp')
ax3.set_ylabel('Altitude')
ax3.legend(loc='best')

plt.show()

# %%
import nbconvert
