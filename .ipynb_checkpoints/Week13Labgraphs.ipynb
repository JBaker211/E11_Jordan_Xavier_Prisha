# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_radiation = pd.read_csv('downloads/radiation.csv')

# %%
radiation_data = data_radiation.loc[1:,"timestamp":"cps_err"]

# %%
#Radiation Frequency levels
y1 = radiation_data['cps'] 
plt.hist(y1, label = 'CPS')
plt.ylabel('Frequency')
plt.xlabel('CPS')
plt.title('CPS Frequency')
plt.show()

# %%
y1 = radiation_data['cps'] 
x1 = radiation_data['timestamp'] 
y1err= radiation_data['cps_err']
# plot:
fig=plt.figure(figsize=(15, 7))
plt.errorbar(x1, y1, y1err, fmt='o', linewidth=1, capsize=4)
plt.plot(x1, y1, label = 'CPS', color ='tab:blue')
plt.xlabel('Time')
plt.ylabel('Counts per 10 seconds')
plt.ylim(-.05,0.75)
plt.title('Counts per 10 seconds vs Time')
fig.savefig('radiation.png', dpi=200)
plt.show()
#need to change export figure to change fig size to put on lab report

# %%
print(f"The mean for our Radiation data is {np.mean(radiation_data['cps'])}")
print(f"The standard deviation for our Radiation data is {np.std(radiation_data['cps'])}")
print(f"The theoretical uncertainty for our Radiation data is {np.sqrt(np.mean(radiation_data['cps']))}")
# Out:
# The mean for our Radiation data is 0.05180722891566265
# The standard deviation for our Radiation data is 0.07556179808123195
# The theoretical uncertainty for our Radiation data is 0.22761201399676304

# %%
data_pth = pd.read_csv('downloads/pth.csv')

# %%
pth_data = data_pth.loc[1:,"timestamp":"alt_err"]
#pth_data

# %%
#Temperature
y2 = pth_data['temp_mean'] 
plt.hist(y2, label = 'Temperature mean')
plt.ylabel('Frequency')
plt.xlabel('Temperature mean')
plt.title('Temperature mean Frequency')
plt.show()

# %%
y2 = pth_data['temp_mean'] 
x2 = pth_data['timestamp'] 
y2err= pth_data['temp_err']
# plot:
fig=plt.figure(figsize=(15, 7))
plt.errorbar(x2, y2, y2err, fmt='o', linewidth=2, capsize=4)
plt.plot(x2, y2, label = 'NAME', color ='tab:blue')
plt.xlabel('Time')
plt.ylabel('Temperature in C')
plt.title('Temperature vs Time')
plt.show()

# %%
print(f"The mean for our Temeprature data is {np.mean(pth_data['temp_mean'])}")
print(f"The standard deviation for our Temperature data is {np.std(pth_data['temp_mean'])}")
print(f"The theoretical uncertainty for our Temperature data is {np.sqrt(np.mean(pth_data['temp_mean']))}")
# Out:
# The mean for our Temeprature data is 25.653299560546873
# The standard deviation for our Temperature data is 0.49365517748614596
# The theoretical uncertainty for our Temperature data is 5.064908642862857

# %%
data_air_quality = pd.read_csv('downloads/air_quality.csv')

# %%
air_data = data_air_quality.loc[1:,"timestamp":"pm10_err"]
#air_data

# %%
#PM2.5 concentration data 2.5um 
y3 = air_data['pm25_mean'] 
plt.hist(y3, label = '2.5um')
plt.xlabel('2.5um')
plt.ylabel('Frequency')
plt.title('2.5um Frequency')
plt.show()

# %%
y3 = air_data['pm25_mean'] 
x3 = air_data['timestamp'] 
y3err= air_data['pm25_err']
# plot:
plt.errorbar(x3, y3, y3err, fmt='o', linewidth=2, capsize=4)
plt.plot(x3, y3, label = '2.5um particles', color ='tab:blue')
plt.xlabel('Time')
plt.ylabel('2.5um particles')
plt.title('2.5um particles vs Time')
plt.show()

# %%
print(f"The mean for our PM2.5 concentration data is {np.mean(air_data['pm25_mean'])}")
print(f"The standard deviation for our PM2.5 concentration data is {np.std(air_data['pm25_mean'])}")
print(f"The theoretical uncertainty for our PM2.5 concentration data is {np.sqrt(np.mean(air_data['pm25_mean']))}")
# Out:
# The mean for our PM2.5 concentration data is 0.0
# The standard deviation for our PM2.5 concentration data is 0.0
# The theoretical uncertainty for our PM2.5 concentration data is 0.0

# %%
#PM2.5 concentration data 
y4 = air_data['pm1_mean'] 
plt.hist(y4, label = '1um')
plt.xlabel('1um')
plt.ylabel('Frequency')
plt.title('1um Frequency')
plt.show()

# %%
y4 = air_data['pm1_mean'] 
x4 = air_data['timestamp'] 
y4err= air_data['pm1_err']
# plot:
plt.errorbar(x4, y4, y4err, fmt='o', linewidth=2, capsize=4)
plt.plot(x4, y4, label = '1um', color ='tab:blue')
plt.xlabel('Time')
plt.ylabel('1um concentration')
plt.title('1um concentration vs Time')
plt.show()

# %%
print(f"The mean for our PM2.5 concentration data is {np.mean(air_data['pm1_mean'])}")
print(f"The standard deviation for our PM2.5 concentration data is {np.std(air_data['pm1_mean'])}")
print(f"The theoretical uncertainty for our PM2.5 concentration data is {np.sqrt(np.mean(air_data['pm1_mean']))}")
# Out:
# The mean for our PM2.5 concentration data is 0.0
# The standard deviation for our PM2.5 concentration data is 0.0
# The theoretical uncertainty for our PM2.5 concentration data is 0.0

# %%
#PM2.5 concentration data 10um 
y5 = air_data['pm10_mean'] 
plt.hist(y5, label = '10um')
plt.xlabel('10um')
plt.ylabel('Frequency')
plt.title('10um Frequency')
plt.show()

# %%
y5 = air_data['pm10_mean'] 
x5 = air_data['timestamp'] 
y5err= air_data['pm10_err']
# plot:
plt.errorbar(x5, y5, y5err, fmt='o', linewidth=2, capsize=4)
plt.plot(x5, y5, label = '10um', color ='tab:blue')
plt.xlabel('Time')
plt.ylabel('10um concentration')
plt.title('10um concentration vs Time')
plt.show()

# %%
print(f"The mean for our PM2.5 concentration data is {np.mean(air_data['pm1_mean'])}")
print(f"The standard deviation for our PM2.5 concentration data is {np.std(air_data['pm1_mean'])}")
print(f"The theoretical uncertainty for our PM2.5 concentration data is {np.sqrt(np.mean(air_data['pm1_mean']))}")
# Out:
# The mean for our PM2.5 concentration data is 0.0
# The standard deviation for our PM2.5 concentration data is 0.0
# The theoretical uncertainty for our PM2.5 concentration data is 0.0
