# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_NAME = pd.read_csv('downloads/FILENAME.csv')
data_NAME = pd.read_csv('downloads/FILENAME.csv')
data_NAME = pd.read_csv('downloads/FILENAME.csv')
data_NAME = pd.read_csv('downloads/FILENAME.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data_NAME = pd.read_csv('downloads/FILENAME.csv')
#       2 data_NAME = pd.read_csv('downloads/FILENAME.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
NAME_data = data_NAME.loc[1:,"Time":"Counts"]
NAME_data = data_NAME.loc[1:,"Time":"Counts"]
NAME_data = data_NAME.loc[1:,"Time":"Counts"]
NAME_data = data_NAME.loc[1:,"Time":"Counts"]

# %%
y1 = NAME_data['Counts'] 
y2 = NAME_data['Counts'] 
y3 = NAME_data['Counts'] 
y4 = NAME_data['Counts'] 
plt.plot(y1, label = '______')
plt.xlabel('Time')
plt.ylabel('Counts')
plt.title('Counts Frequency')
plt.legend()
plt.show()

# %%
#Comparing Standard deviation to mean
NAME_column_name_list = list(NAME_data.columns)
NAME_standard_deviations = []
NAME_standard_means = []
NAME_trial_uncs = []

for i in range(NAME_data.shape[1]):
    NAME_column_data = NAME_data[NAME_column_name_list[i]] 
    NAME_standard_deviations.append(np.std(NAME_column_data))
    NAME_standard_means.append(NAME_standard_deviations[i] / np.sqrt(len(NAME_column_data)))

    # mean uncertainty for each NAME data column
    NAME_trial_unc =  np.sqrt(sum(NAME_column_data))/(len(NAME_column_data))
    NAME_trial_uncs.append(NAME_trial_unc)
    print(f"The mean uncertainty for {NAME_column_name_list[i]} (for our counts data) is " + str(NAME_trial_unc))
#Next Set of data
NAME_column_name_list = list(NAME_data.columns)
NAME_standard_deviations = []
NAME_standard_means = []
NAME_trial_uncs = []


for i in range(NAME_data.shape[1]):
    NAME_column_data = NAME_data[NAME_column_name_list[i]] 
    NAME_standard_deviations.append(np.std(NAME_column_data))
    NAME_standard_means.append(NAME_standard_deviations[i] / np.sqrt(len(NAME_column_data)))

    # mean uncertainty for each NAME data column
    NAME_trial_unc =  np.sqrt(sum(NAME_column_data))/(len(NAME_column_data))
    NAME_trial_uncs.append(NAME_trial_unc)
    print(f"The mean uncertainty for {NAME_column_name_list[i]} (for our counts data) is " + str(NAME_trial_unc))

#Next Set of data
NAME_column_name_list = list(NAME_data.columns)
NAME_standard_deviations = []
NAME_standard_means = []
NAME_trial_uncs = []
#Next Set of data
for i in range(NAME_data.shape[1]):
    NAME_column_data = NAME_data[NAME_column_name_list[i]] 
    NAME_standard_deviations.append(np.std(NAME_column_data))
    NAME_standard_means.append(NAME_standard_deviations[i] / np.sqrt(len(NAME_column_data)))

    # mean uncertainty for each NAME data column
    NAME_trial_unc =  np.sqrt(sum(NAME_column_data))/(len(NAME_column_data))
    NAME_trial_uncs.append(NAME_trial_unc)
    print(f"The mean uncertainty for {NAME_column_name_list[i]} (for our counts data) is " + str(NAME_trial_unc))

#Next Set of data
NAME_column_name_list = list(NAME_data.columns)
NAME_standard_deviations = []
NAME_standard_means = []
NAME_trial_uncs = []

for i in range(NAME_data.shape[1]):
    NAME_column_data = NAME_data[NAME_column_name_list[i]] 
    NAME_standard_deviations.append(np.std(NAME_column_data))
    NAME_standard_means.append(NAME_standard_deviations[i] / np.sqrt(len(NAME_column_data)))

    # mean uncertainty for each NAME data column
    NAME_trial_unc =  np.sqrt(sum(NAME_column_data))/(len(NAME_column_data))
    NAME_trial_uncs.append(NAME_trial_unc)
    print(f"The mean uncertainty for {NAME_column_name_list[i]} (for our counts data) is " + str(NAME_trial_unc))

# %%
#How do the measured standard deviations compare to the theoretical uncertainty you
#would expect from counting statistics?

# %%
#What general trend do you see in the counts measured as a function of the thickness of
#absorber material?

# %%
#Graphing different thickness
y1 = 
y2 = 
y1err= 
y2err = 
# plot:
plt.errorbar(x, y1, y1err, fmt='o', linewidth=2, capsize=6)
plt.show()
plt.plot(y1, label = 'Outside')
plt.plot(y2,label = 'Inside')
plt.xlabel('Time')
plt.yscale('log')
plt.ylabel('Particles 0.3um')
plt.title('Pm particles 0.3um vs Time')
plt.legend()
plt.show()
# Out:
#   Cell In[2], line 2
#     y1 =
#          ^
# SyntaxError: invalid syntax

# %%
# Do these graphs follow the trend you expect?

# %%
#Do this same analysis for the second source. Do you expect the measured absorption coefficients
#to be the same? Why might you find differences?
